# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('data/food_coded.csv')

# %%
# Set the display options to show all columns and rows without truncation
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.width', None)

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  cook  comfort_food_reasons_coded.1  cuisine  \
# 0                         9.0   2.0                             9      NaN
# 1                         1.0   3.0                             1      1.0
# 2                         1.0   1.0                             1      3.0
# 3                         2.0   2.0                             2      2.0
# 4                         1.0   1.0                             1      2.0
#
#                                         diet_current  diet_current_coded  \
# 0                              eat good and exercise                   1
# 1  I eat about three times a day with some snacks...                   2
# 2  toast and fruit for breakfast, salad for lunch...                   3
# 3  College diet, cheap and easy foods most nights...                   2
# 4  I try to eat healthy but often struggle becaus...                   2
#
#    drink                                     eating_changes  \
# 0    1.0                                        eat faster
# 1    2.0                        I eat out more than usual.
# 2    1.0  sometimes choosing to eat fast food instead of...
# 3    2.0     Accepting cheap and premade/store bought foods
# 4    2.0  I have eaten generally the same foods but I do...
#
#    eating_changes_coded  eating_changes_coded1  eating_out  employment  \
# 0                     1                      1           3         3.0
# 1                     1                      2           2         2.0
# 2                     1                      3           2         3.0
# 3                     1                      3           2         3.0
# 4                     3                      4           2         2.0
#
#    ethnic_food  exercise  father_education father_profession     fav_cuisine  \
# 0            1       1.0               5.0         profesor   Arabic cuisine
# 1            4       1.0               2.0    Self employed          Italian
# 2            5       2.0               2.0     owns business         italian
# 3            5       3.0               2.0         Mechanic         Turkish
# 4            4       1.0               4.0                IT        Italian
#
#    fav_cuisine_coded  fav_food                                food_childhood  \
# 0                  3       1.0                            rice  and chicken
# 1                  1       1.0  chicken and biscuits, beef soup, baked beans
# 2                  1       3.0                  mac and cheese, pizza, tacos
# 3                  3       1.0                 Beef stroganoff, tacos, pizza
# 4                  1       3.0                 Pasta, chicken tender, pizza
#
#    fries  fruit_day  grade_level  greek_food  healthy_feeling  \
# 0      2          5            2           5                2
# 1      1          4            4           4                5
# 2      1          5            3           5                6
# 3      2          4            4           5                7
# 4      1          4            4           4                6
#
#                                         healthy_meal  \
# 0                                    looks not oily
# 1  Grains, Veggies, (more of grains and veggies),...
# 2  usually includes natural ingredients; nonproce...
# 3           Fresh fruits& vegetables, organic meats
# 4  A lean protein such as grilled chicken, green ...
#
#                                           ideal_diet  ideal_diet_coded  \
# 0                                     being healthy                  8
# 1  Try to eat 5-6 small meals a day. While trying...                 3
# 2       i would say my ideal diet is my current diet                 6
# 3     Healthy, fresh veggies/fruits & organic foods                  2
# 4  Ideally I would like to be able to eat healthi...                 2
#
#    income  indian_food  italian_food  life_rewarding  marital_status  \
# 0     5.0            5             5             1.0             1.0
# 1     4.0            4             4             1.0             2.0
# 2     6.0            5             5             7.0             2.0
# 3     6.0            5             5             2.0             2.0
# 4     6.0            2             5             1.0             1.0
#
#                                  meals_dinner_friend  mother_education  \
# 0                               rice, chicken,  soup               1.0
# 1                             Pasta, steak, chicken                4.0
# 2  chicken and rice with veggies, pasta, some kin...               2.0
# 3   Grilled chicken \rStuffed Shells\rHomemade Chili               4.0
# 4  Chicken Parmesan, Pulled Pork, Spaghetti and m...               5.0
#
#            mother_profession  nutritional_check  on_off_campus  parents_cook  \
# 0                 unemployed                  5            1.0             1
# 1                  Nurse RN                   4            1.0             1
# 2              owns business                  4            2.0             1
# 3  Special Education Teacher                  2            1.0             1
# 4   Substance Abuse Conselor                  3            1.0             1
#
#    pay_meal_out  persian_food  self_perception_weight  soup  sports  \
# 0             2           5.0                     3.0   1.0     1.0
# 1             4           4.0                     3.0   1.0     1.0
# 2             3           5.0                     6.0   1.0     2.0
# 3             2           5.0                     5.0   1.0     2.0
# 4             4           2.0                     4.0   1.0     1.0
#
#    thai_food  tortilla_calories  turkey_calories  type_sports  veggies_day  \
# 0          1             1165.0              345   car racing            5
# 1          2              725.0              690  Basketball             4
# 2          5             1165.0              500         none            5
# 3          5              725.0              690          NaN            3
# 4          4              940.0              500     Softball            4
#
#    vitamins  waffle_calories                    weight
# 0         1             1315                       187
# 1         2              900                       155
# 2         1              900  I'm not answering this.
# 3         1             1315             Not sure, 240
# 4         2              760                       190

# %% [markdown]
# # **<font color="red">if you have any unnecessary column drop them here</font>**

# %%
# drop column here
df.drop(['waffle_calories','turkey_calories','tortilla_calories'],inplace=True,axis=1)

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  cook  comfort_food_reasons_coded.1  cuisine  \
# 0                         9.0   2.0                             9      NaN
# 1                         1.0   3.0                             1      1.0
# 2                         1.0   1.0                             1      3.0
# 3                         2.0   2.0                             2      2.0
# 4                         1.0   1.0                             1      2.0
#
#                                         diet_current  diet_current_coded  \
# 0                              eat good and exercise                   1
# 1  I eat about three times a day with some snacks...                   2
# 2  toast and fruit for breakfast, salad for lunch...                   3
# 3  College diet, cheap and easy foods most nights...                   2
# 4  I try to eat healthy but often struggle becaus...                   2
#
#    drink                                     eating_changes  \
# 0    1.0                                        eat faster
# 1    2.0                        I eat out more than usual.
# 2    1.0  sometimes choosing to eat fast food instead of...
# 3    2.0     Accepting cheap and premade/store bought foods
# 4    2.0  I have eaten generally the same foods but I do...
#
#    eating_changes_coded  eating_changes_coded1  eating_out  employment  \
# 0                     1                      1           3         3.0
# 1                     1                      2           2         2.0
# 2                     1                      3           2         3.0
# 3                     1                      3           2         3.0
# 4                     3                      4           2         2.0
#
#    ethnic_food  exercise  father_education father_profession     fav_cuisine  \
# 0            1       1.0               5.0         profesor   Arabic cuisine
# 1            4       1.0               2.0    Self employed          Italian
# 2            5       2.0               2.0     owns business         italian
# 3            5       3.0               2.0         Mechanic         Turkish
# 4            4       1.0               4.0                IT        Italian
#
#    fav_cuisine_coded  fav_food                                food_childhood  \
# 0                  3       1.0                            rice  and chicken
# 1                  1       1.0  chicken and biscuits, beef soup, baked beans
# 2                  1       3.0                  mac and cheese, pizza, tacos
# 3                  3       1.0                 Beef stroganoff, tacos, pizza
# 4                  1       3.0                 Pasta, chicken tender, pizza
#
#    fries  fruit_day  grade_level  greek_food  healthy_feeling  \
# 0      2          5            2           5                2
# 1      1          4            4           4                5
# 2      1          5            3           5                6
# 3      2          4            4           5                7
# 4      1          4            4           4                6
#
#                                         healthy_meal  \
# 0                                    looks not oily
# 1  Grains, Veggies, (more of grains and veggies),...
# 2  usually includes natural ingredients; nonproce...
# 3           Fresh fruits& vegetables, organic meats
# 4  A lean protein such as grilled chicken, green ...
#
#                                           ideal_diet  ideal_diet_coded  \
# 0                                     being healthy                  8
# 1  Try to eat 5-6 small meals a day. While trying...                 3
# 2       i would say my ideal diet is my current diet                 6
# 3     Healthy, fresh veggies/fruits & organic foods                  2
# 4  Ideally I would like to be able to eat healthi...                 2
#
#    income  indian_food  italian_food  life_rewarding  marital_status  \
# 0     5.0            5             5             1.0             1.0
# 1     4.0            4             4             1.0             2.0
# 2     6.0            5             5             7.0             2.0
# 3     6.0            5             5             2.0             2.0
# 4     6.0            2             5             1.0             1.0
#
#                                  meals_dinner_friend  mother_education  \
# 0                               rice, chicken,  soup               1.0
# 1                             Pasta, steak, chicken                4.0
# 2  chicken and rice with veggies, pasta, some kin...               2.0
# 3   Grilled chicken \rStuffed Shells\rHomemade Chili               4.0
# 4  Chicken Parmesan, Pulled Pork, Spaghetti and m...               5.0
#
#            mother_profession  nutritional_check  on_off_campus  parents_cook  \
# 0                 unemployed                  5            1.0             1
# 1                  Nurse RN                   4            1.0             1
# 2              owns business                  4            2.0             1
# 3  Special Education Teacher                  2            1.0             1
# 4   Substance Abuse Conselor                  3            1.0             1
#
#    pay_meal_out  persian_food  self_perception_weight  soup  sports  \
# 0             2           5.0                     3.0   1.0     1.0
# 1             4           4.0                     3.0   1.0     1.0
# 2             3           5.0                     6.0   1.0     2.0
# 3             2           5.0                     5.0   1.0     2.0
# 4             4           2.0                     4.0   1.0     1.0
#
#    thai_food  type_sports  veggies_day  vitamins                    weight
# 0          1   car racing            5         1                       187
# 1          2  Basketball             4         2                       155
# 2          5         none            5         1  I'm not answering this.
# 3          5          NaN            3         1             Not sure, 240
# 4          4     Softball            4         2                       190

# %%
import nbformat

# Assuming header is a list of strings
# header = ["header1", "header2", "header3"]
columns = df.columns.tolist()

# initial cells
initial_cells = [
    nbformat.v4.new_code_cell(source='import pandas as pd\nimport numpy as np\nimport seaborn as sns\nimport matplotlib.pyplot as plt\nimport warnings\n%matplotlib inline\nsns.set()\n# Filter out the warning about deprecated distplot\nwarnings.filterwarnings("ignore")'),
    nbformat.v4.new_code_cell(source="# Set the display options to show all columns and rows without truncation\npd.set_option('display.max_columns', None)"),
    nbformat.v4.new_code_cell(source="df = pd.read_csv('data/food_coded.csv')"),
    nbformat.v4.new_code_cell(source='df.head()'),
    nbformat.v4.new_code_cell(source='label = {}'),
    nbformat.v4.new_code_cell(source="def remove_outliers(df, column_name):\n    # Step 1: Calculate the IQR for the specified column\n    q1 = df[column_name].quantile(0.25)\n    q3 = df[column_name].quantile(0.75)\n    iqr = q3 - q1\n    # Step 2: Define the lower and upper bounds for outlier removal\n    lower_bound = q1 - 1.5 * iqr\n    upper_bound = q3 + 1.5 * iqr\n    # Step 3: Update the specified column with the cleaned data\n    df[f'{column_name}_01'] = np.where(\n        (df[column_name] >= lower_bound) & (df[column_name] <= upper_bound),\n        df[column_name],\n        np.nan\n    )")
]

final_notebook = nbformat.v4.new_notebook()
final_notebook.cells.extend(initial_cells)

for col in columns:
    func_strings1 = "**clean data here**<br>1. remove nan(null values)<br>&nbsp;&nbsp;&nbsp;&nbsp;* remove null<br>&nbsp;&nbsp;&nbsp;&nbsp;* replace null(mean, median, mode)<br>"
    func_strings2 = "<br>2. organize the data using domain knowledge<br>3. don't map the value yet we will give labels later"
    nb = nbformat.v4.new_notebook()
    final = []
    cells = [
        nbformat.v4.new_markdown_cell(source='<hr style="border: 2px solid purple;">'),
        nbformat.v4.new_markdown_cell(source=f'# **<font size=17px color="yellow">{col}</font>**'),
        nbformat.v4.new_code_cell(source=f"df['{col}'].head(10)"),
        nbformat.v4.new_markdown_cell(source="#### <font size=7px color='blue'>check the data</font>"),
        nbformat.v4.new_code_cell(source=f"print('null value in {col} == {{}}'.format(df.{col}.isnull().sum()))"),
        nbformat.v4.new_code_cell(source=f"print(f'there are _ {{df.{col}.nunique()}} _ unique values')"),
        nbformat.v4.new_code_cell(source=f"print(f'top 5 unique values:\\nvalue - count : {{df.{col}.value_counts()[:5]}}\\n\\n***\\n\\nbottom 5 unique value:\\nvalue - count :  {{df.{col}.value_counts()[-5:]}}')"),
        nbformat.v4.new_markdown_cell(source="#### <font size= 7px color='blue'>dtype</font>"),
        nbformat.v4.new_code_cell(source=f"df.{col}.dtype\n# format if dtype is wrong"),
        nbformat.v4.new_code_cell(source=f"## see non numeric value in column\n\n## Convert the column to numeric, coercing non-numeric values to NaN\n# numeric_column = pd.to_numeric(df.{col}, errors='coerce')\n\n## Identify non-numeric values using boolean indexing\n# non_numeric_value = df.{col}[numeric_column.isna()]\n# print(non_numeric_value)"),
        nbformat.v4.new_code_cell(source='# format opreation'),
        nbformat.v4.new_code_cell(source=f"# if dtype is numeric skip this 2 cell\n{col} = {{'labels your data here'}} # label data in 'key': value pair\nlabel['{col}'] = {col} # store data label dict in main dict actually it's updating/"),
        nbformat.v4.new_code_cell(source=f"# df['{col}'].replace({col}, inplace=True)\n# print('Modified DataFrame:')\n# print(df['{col}'].head(10))"),
        nbformat.v4.new_markdown_cell(source="#### <font size=7px color = 'blue'>clean data here</font>"),
        nbformat.v4.new_code_cell(source=f"## for removing null value\n# df.dropna(subset=['{col}'], inplace=True)"),
        nbformat.v4.new_code_cell(source=f"# First plot - Distribution plot\nplt.figure(figsize=(10, 7))\nsns.distplot(df['{col}'])\nplt.title('Distribution Plot for {col}')  # Title for the plot\nplt.xlabel('{col} Values')  # X-axis label\nplt.ylabel('Density')  # Y-axis label\n\n# Second plot - Boxplot\nplt.figure(figsize=(10, 7))\nsns.boxplot(df['{col}'],orient='h')\nplt.title('Box Plot for {col}')  # Title for the plot\nplt.xlabel('{col}')  # X-axis label\nplt.ylabel('{col} values')"),
        nbformat.v4.new_markdown_cell(source="<font size=5px color='bblue'> # type some insight here </font>"),
        nbformat.v4.new_code_cell(source=f"# mean = df['{col}'].mean()\n# print(mean)\n\n# median = df['{col}'].median()\n# print(median)\n\n# mode = df['{col}'].mode()\n# print(mode)"),
        nbformat.v4.new_code_cell(source=f"## Example 1: Replace missing values in a numerical column with the mean\n# df['{col}'].fillna(df['{col}'].mean(), inplace=True)\n\n## Example 2: Replace missing values in a numerical column with the median\n# df['{col}'].fillna(df['{col}'].median(), inplace=True)\n\n## Example 3: if **non-numeric**\n\n# df['{col}'].value_counts()\n\n ## Replace missing values in a categorical column with the mode\n# df['{col}'].fillna(df['{col}'].mode()[0], inplace=True)"),
        nbformat.v4.new_markdown_cell(source="#### <font size=7px color = 'blue'>outliers</font>"),
        nbformat.v4.new_code_cell(source=f"# remove_outliers(df,'{col}')"),
        nbformat.v4.new_code_cell(source=f"# print('null value in {col}_01 == {{}}'.format(df.{col}_01.isnull().sum()))"),
        nbformat.v4.new_code_cell(source=f"## Example 1: Replace missing values in a numerical column with the mean\n# df['{col}_01'].fillna(df['{col}_01'].mean(), inplace=True)\n\n## Example 2: Replace missing values in a numerical column with the median\n# df['{col}_01'].fillna(df['{col}_01'].median(), inplace=True)\n\n## Example 3: if **non-numeric**\n\n# df['{col}_01'].value_counts()\n\n ## Replace missing values in a categorical column with the mode\n# df['{col}_01'].fillna(df['{col}_01'].mode()[0], inplace=True)"),
        nbformat.v4.new_markdown_cell(source="#### **<font size = 7px color = 'lime'>verify the process</font>**"),
        nbformat.v4.new_code_cell(source="df.head()"),
        nbformat.v4.new_code_cell(source=f"print('null value in {col} == {{}}'.format(df.{col}.isnull().sum()))\n# print('\\n---\\n')\n# print('null value in {col}_01 == {{}}'.format(df.{col}_01.isnull().sum()))"),
        nbformat.v4.new_code_cell(source=f"print(f'The dtype of {col} is {{df.{col}.dtype}}')\n# print('\\n---\\n')\n# print(f'The dtype of {col}_01 is {{df.{col}_01.dtype}}')"),
        nbformat.v4.new_code_cell(source=f"## First plot - Distribution plot\n# plt.figure(figsize=(10, 7))\n# sns.distplot(df['{col}_01'])\n# plt.title('Distribution Plot for {col}_01')  ## Title for the plot\n# plt.xlabel('{col}_01 Values')  ## X-axis label\n# plt.ylabel('Density')  ## Y-axis label\n\n## Second plot - Boxplot\n# plt.figure(figsize=(10, 7))\n# sns.boxplot(df['{col}_01'],orient='h')\n# plt.title('Box Plot for {col}_01')  ## Title for the plot\n# plt.xlabel('{col}_01')  ## X-axis label\n# plt.ylabel('{col}_01 values')"),
        nbformat.v4.new_code_cell(source="# more plot ?\n"),
        nbformat.v4.new_markdown_cell(source="<font size=5px color='bblue'> # type some insight here </font>"),
    ]


    final.extend(cells)
    nb['cells'] = final

    ## Append the cells of each notebook to the final notebook
    final_notebook.cells.extend(nb['cells'])

# Write the final combined notebook to a new file
nbformat.write(final_notebook, 'clean.ipynb')

## Save the final combined notebook back to the same file
# with open('project_2.ipynb', 'w') as f:
#     nbformat.write(final_notebook, f)
